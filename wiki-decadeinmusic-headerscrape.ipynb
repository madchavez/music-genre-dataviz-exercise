# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
def extract_headers(url):
    try:
        # Fetch the webpage
        headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
        }
        response = requests.get(url, headers=headers)
        response.raise_for_status()  # Raise an error for bad status codes
        
        # Parse the HTML content
        soup = BeautifulSoup(response.text, 'html.parser')
        
        # Find all h3 and h4 elements
        h3_headers = soup.find_all('h3')
        h4_headers = soup.find_all('h4')
        
        # Extract and clean the text
        h3_texts = [h3.get_text(strip=True) for h3 in h3_headers]
        h4_texts = [h4.get_text(strip=True) for h4 in h4_headers]
        
        return {
            'h3_headers': h3_texts,
            'h4_headers': h4_texts
        }
        
    except requests.exceptions.RequestException as e:
        print(f"Error fetching the URL: {e}")
        return None
    except Exception as e:
        print(f"An error occurred: {e}")
        return None

# %%
year = 1940
data = []
while year < 2030:
    url = f"https://en.wikipedia.org/wiki/{year}s_in_music"
    headers = extract_headers(url)
    if headers:
        print("\nH3 Headers:")
        for i, header in enumerate(headers['h3_headers'], 1):
            print(f"{i}. {header}")
            data.append([f"{year}s", header])
            
        print("\nH4 Headers:")
        for i, header in enumerate(headers['h4_headers'], 1):
            print(f"{i}. {header}")
            data.append([f"{year}s", header])
    else:
        print("Failed to extract headers.")

    year += 10

print(data)
df = pd.DataFrame(data, columns=['decade','headers'])
# Out:
# H3 Headers:
# 1. Pop
# 2. Best Selling Records of Decade 1940s
# 3. Jazz
# 4. Country music
# 5. Other Trends
#
# H4 Headers:
#
# H3 Headers:
# 1. Rock and roll
# 2. Classic pop
# 3. R&B
# 4. Blues
# 5. Country music
# 6. Jazz
# 7. Other trends
# 8. Folk music
# 9. France
#
# H4 Headers:
#
# H3 Headers:
# 1. Beat music and the British Invasion
# 2. British blues boom
# 3. British psychedelia
# 4. Folk music
# 5. Rock
# 6. Psychedelic rock
# 7. Surf rock
# 8. Garage rock
# 9. Blues-rock
# 10. Roots rock
# 11. Progressive rock
# 12. Pop
# 13. R&B, Motown and soul music
# 14. Country music
# 15. Other trends and musical events
# 16. Bossa Nova
# 17. Romantics
# 18. Nueva ola
# 19. Nueva canción
# 20. Salsa
# 21. Tango
# 22. Música cebolla
# 23. Sources
#
# H4 Headers:
#
# H3 Headers:
# 1. Rock
# 2. Pop
# 3. Disco, R&B and urban
# 4. Soft rock and pop
# 5. Punk rock
# 6. Hard rock, arena rock and heavy metal
# 7. Progressive rock
# 8. New wave
# 9. Blues rock
# 10. Country
# 11. Other developments
# 12. Japan
# 13. Hong Kong
# 14. Southeast Asia
# 15. Nueva canción
# 16. Rock
# 17. Tropical
# 18. Reggae and Afrobeat
# 19. Cumbia
# 20. Salsa and merengue
#
# H4 Headers:
# 1. Hard rock and early metal
# 2. Progressive rock
# 3. Glam rock
# 4. Soft rock
# 5. Punk rock
# 6. New wave
# 7. Country rock and Southern rock
# 8. Notable deaths in country music
#
# H3 Headers:
# 1. Pop
# 2. Rock
# 3. Contemporary R&B
# 4. Hip hop
# 5. Electronic
# 6. Country
# 7. Rock
# 8. Pop
# 9. Pop
# 10. Rock
# 11. Salsa
# 12. Merengue
# 13. Japan
# 14. Hong Kong
# 15. Indonesia
#
# H4 Headers:
# 1. Hard rock and heavy/glam metal
# 2. Alternative rock
# 3. Other trends
# 4. Post-punk
# 5. New wave
# 6. New Romantics
# 7. Gothic rock
# 8. Heavy metal
# 9. Synthpop
# 10. Italy
# 11. Netherlands
# 12. Germany
# 13. Austria
#
# H3 Headers:
# 1. Rock
# 2. Pop
# 3. Contemporary R&B
# 4. Neo-soul
# 5. Hip hop
# 6. Electronic music
# 7. Country music
# 8. Jazz
# 9. Rock
# 10. Pop
# 11. Electronic music
# 12. Pop
# 13. Rock
# 14. Salsa
# 15. Cumbia
# 16. Japanese rock
# 17. J-pop
# 18. C-pop
# 19. Filipino pop
#
# H4 Headers:
# 1. Alternative rock
# 2. Skate punk and pop punk
# 3. Heavy metal
# 4. Pop rock
# 5. Hard rock
# 6. Adult contemporary
# 7. Swing revival
# 8. Madchester
# 9. Britpop
# 10. Post-Britpop
# 11. Shoegaze
# 12. Other trends
# 13. United Kingdom
#
# H3 Headers:
# 1. Hip hop
# 2. Rock
# 3. Pop
# 4. Adult contemporary
# 5. Contemporary R&B
# 6. Country
# 7. Electronic music
# 8. Jazz
# 9. Reggae
# 10. Christian music
# 11. Rock
# 12. Alternative rock
# 13. Pop
# 14. Soul
# 15. Electronic music
# 16. Pop
# 17. Rock
# 18. R&B and soul
# 19. Hip hop
# 20. Pop
# 21. Rock
# 22. Reggaetón
# 23. Salsa and merengue
# 24. C-pop
# 25. J-pop
# 26. K-pop
# 27. Indian pop
# 28. Indo pop
# 29. P-pop
# 30. Afrobeats
# 31. Arabic pop music
# 32. Drum and bass
# 33. Hip hop
#
# H4 Headers:
# 1. Pop rock
# 2. Pop punk
# 3. Post-grunge
# 4. Nu metal
# 5. Metalcore
# 6. Hard rock/Heavy metal
# 7. Emo
# 8. Garage rock, post-punk and new wave revival
# 9. Indie rock
# 10. Dancehall
# 11. Reggaetón
# 12. Alternative
# 13. Botswana
# 14. Côte d'Ivoire
# 15. Madagascar
# 16. Malawi
# 17. Niger
# 18. Palestine
# 19. Uganda
# 20. Zambia
#
# H3 Headers:
# 1. Pop
# 2. Rock
# 3. Pop rock
# 4. Contemporary R&B and soul
# 5. Hip-hop
# 6. Electronic
# 7. Indie
# 8. Country
# 9. Christian
# 10. Pop
# 11. Soul
# 12. Rock
# 13. Folk
# 14. Electronic
# 15. Pop
# 16. Electropop
# 17. Contemporary R&B
# 18. Hardstyle
# 19. Future garage and Australian sound
# 20. Metalcore and hardcore punk
# 21. Neo-psychedelia
# 22. Pop and reggaeton
# 23. Hip-hop
# 24. K-pop
# 25. J-pop
# 26. C-pop
# 27. Hip-hop
# 28. Electropop and rock
# 29. Rap
# 30. Afrobeats
#
# H4 Headers:
# 1. Alternative rock
# 2. Psychedelic rock
# 3. Progressive and experimental rock
# 4. Pop punk and punk rock
# 5. Hard rock and heavy metal
# 6. Blog rap
# 7. Mumble rap
# 8. Trap
# 9. Emo rap
# 10. Alternative rap and industrial hip-hop
# 11. Jazzhop and lofi hip-hop
# 12. Hyperpop
# 13. Indie folk
# 14. Bedroom pop
# 15. Hip-hop's influence on country
# 16. Tragedy and deaths of classic stars
#
# H3 Headers:
# 1. Impact of COVID-19
# 2. Impact of social media
# 3. Trends and statistics
# 4. Highlights (2020 to late 2022)
# 5. Pop
# 6. Hip hop
# 7. Contemporary R&B and soul
# 8. Indie & alternative
# 9. Country
# 10. Rock
# 11. Electronic & dance
# 12. Soundtrack
# 13. K-pop
# 14. Korean hip hop and R&B
# 15. Japanese pop
# 16. Mandopop
# 17. Pop
# 18. Rock
# 19. Electronic
# 20. Latin pop
# 21. Reggaeton
# 22. Afrobeats
#
# H4 Headers:
# 1. Legacy media in music
# 2. Breakthroughs in pop music
# 3. Notable pop acts
# 4. Retro pop
# 5. North American Latin pop
# 6. Breakthroughs in rap music
# 7. Rage
# 8. Drift phonk
# 9. Alternative
# 10. Notable alternative acts
# 11. American country music
# 12. Regional Mexican
# 13. Soft rock
# 14. Hard rock and heavy metal
# 15. Punk rock
# 16. Shoegaze
# 17. Hyperpop
# 18. Notable electronic & dance acts
# 19. Jersey club
# 20. Breakcore
# [['1940s', 'Pop'], ['1940s', 'Best Selling Records of Decade 1940s'], ['1940s', 'Jazz'], ['1940s', 'Country music'], ['1940s', 'Other Trends'], ['1950s', 'Rock and roll'], ['1950s', 'Classic pop'], ['1950s', 'R&B'], ['1950s', 'Blues'], ['1950s', 'Country music'], ['1950s', 'Jazz'], ['1950s', 'Other trends'], ['1950s', 'Folk music'], ['1950s', 'France'], ['1960s', 'Beat music and the British Invasion'], ['1960s', 'British blues boom'], ['1960s', 'British psychedelia'], ['1960s', 'Folk music'], ['1960s', 'Rock'], ['1960s', 'Psychedelic rock'], ['1960s', 'Surf rock'], ['1960s', 'Garage rock'], ['1960s', 'Blues-rock'], ['1960s', 'Roots rock'], ['1960s', 'Progressive rock'], ['1960s', 'Pop'], ['1960s', 'R&B, Motown and soul music'], ['1960s', 'Country music'], ['1960s', 'Other trends and musical events'], ['1960s', 'Bossa Nova'], ['1960s', 'Romantics'], ['1960s', 'Nueva ola'], ['1960s', 'Nueva canción'], ['1960s', 'Salsa'], ['1960s', 'Tango'], ['1960s', 'Música cebolla'], ['1960s', 'Sources'], ['1970s', 'Rock'], ['1970s', 'Pop'], ['1970s', 'Disco, R&B and urban'], ['1970s', 'Soft rock and pop'], ['1970s', 'Punk rock'], ['1970s', 'Hard rock, arena rock and heavy metal'], ['1970s', 'Progressive rock'], ['1970s', 'New wave'], ['1970s', 'Blues rock'], ['1970s', 'Country'], ['1970s', 'Other developments'], ['1970s', 'Japan'], ['1970s', 'Hong Kong'], ['1970s', 'Southeast Asia'], ['1970s', 'Nueva canción'], ['1970s', 'Rock'], ['1970s', 'Tropical'], ['1970s', 'Reggae and Afrobeat'], ['1970s', 'Cumbia'], ['1970s', 'Salsa and merengue'], ['1970s', 'Hard rock and early metal'], ['1970s', 'Progressive rock'], ['1970s', 'Glam rock'], ['1970s', 'Soft rock'], ['1970s', 'Punk rock'], ['1970s', 'New wave'], ['1970s', 'Country rock and Southern rock'], ['1970s', 'Notable deaths in country music'], ['1980s', 'Pop'], ['1980s', 'Rock'], ['1980s', 'Contemporary R&B'], ['1980s', 'Hip hop'], ['1980s', 'Electronic'], ['1980s', 'Country'], ['1980s', 'Rock'], ['1980s', 'Pop'], ['1980s', 'Pop'], ['1980s', 'Rock'], ['1980s', 'Salsa'], ['1980s', 'Merengue'], ['1980s', 'Japan'], ['1980s', 'Hong Kong'], ['1980s', 'Indonesia'], ['1980s', 'Hard rock and heavy/glam metal'], ['1980s', 'Alternative rock'], ['1980s', 'Other trends'], ['1980s', 'Post-punk'], ['1980s', 'New wave'], ['1980s', 'New Romantics'], ['1980s', 'Gothic rock'], ['1980s', 'Heavy metal'], ['1980s', 'Synthpop'], ['1980s', 'Italy'], ['1980s', 'Netherlands'], ['1980s', 'Germany'], ['1980s', 'Austria'], ['1990s', 'Rock'], ['1990s', 'Pop'], ['1990s', 'Contemporary R&B'], ['1990s', 'Neo-soul'], ['1990s', 'Hip hop'], ['1990s', 'Electronic music'], ['1990s', 'Country music'], ['1990s', 'Jazz'], ['1990s', 'Rock'], ['1990s', 'Pop'], ['1990s', 'Electronic music'], ['1990s', 'Pop'], ['1990s', 'Rock'], ['1990s', 'Salsa'], ['1990s', 'Cumbia'], ['1990s', 'Japanese rock'], ['1990s', 'J-pop'], ['1990s', 'C-pop'], ['1990s', 'Filipino pop'], ['1990s', 'Alternative rock'], ['1990s', 'Skate punk and pop punk'], ['1990s', 'Heavy metal'], ['1990s', 'Pop rock'], ['1990s', 'Hard rock'], ['1990s', 'Adult contemporary'], ['1990s', 'Swing revival'], ['1990s', 'Madchester'], ['1990s', 'Britpop'], ['1990s', 'Post-Britpop'], ['1990s', 'Shoegaze'], ['1990s', 'Other trends'], ['1990s', 'United Kingdom'], ['2000s', 'Hip hop'], ['2000s', 'Rock'], ['2000s', 'Pop'], ['2000s', 'Adult contemporary'], ['2000s', 'Contemporary R&B'], ['2000s', 'Country'], ['2000s', 'Electronic music'], ['2000s', 'Jazz'], ['2000s', 'Reggae'], ['2000s', 'Christian music'], ['2000s', 'Rock'], ['2000s', 'Alternative rock'], ['2000s', 'Pop'], ['2000s', 'Soul'], ['2000s', 'Electronic music'], ['2000s', 'Pop'], ['2000s', 'Rock'], ['2000s', 'R&B and soul'], ['2000s', 'Hip hop'], ['2000s', 'Pop'], ['2000s', 'Rock'], ['2000s', 'Reggaetón'], ['2000s', 'Salsa and merengue'], ['2000s', 'C-pop'], ['2000s', 'J-pop'], ['2000s', 'K-pop'], ['2000s', 'Indian pop'], ['2000s', 'Indo pop'], ['2000s', 'P-pop'], ['2000s', 'Afrobeats'], ['2000s', 'Arabic pop music'], ['2000s', 'Dru ...

# %%
df
# Out:
#     decade                               headers
# 0    1940s                                   Pop
# 1    1940s  Best Selling Records of Decade 1940s
# 2    1940s                                  Jazz
# 3    1940s                         Country music
# 4    1940s                          Other Trends
# ..     ...                                   ...
# 261  2020s                              Shoegaze
# 262  2020s                              Hyperpop
# 263  2020s       Notable electronic & dance acts
# 264  2020s                           Jersey club
# 265  2020s                             Breakcore
#
# [266 rows x 2 columns]

# %%
df.to_csv('decades-in-music-headers')
