# %%
import os
from dotenv import load_dotenv
import re
import requests
import pandas as pd
import time
import lyricsgenius
import requests

# %%
load_dotenv()

GENIUS_API_KEY = os.getenv("GENIUS_API")
LASTFM_API_KEY = os.getenv("LASTFM_API")
LASTFM_URL = "http://ws.audioscrobbler.com/2.0/"
print("Using Genius API:", GENIUS_API_KEY[:5] + "*****")  # sanity check
print("Using LastFM API:", LASTFM_API_KEY[:5] + "*****")  # sanity check
# Out:
# Using Genius API: co8_v*****
# Using LastFM API: fc10b*****

# %%
genius = lyricsgenius.Genius(GENIUS_API_KEY)
genius.timeout = 15
genius.remove_section_headers = True

# === Last.fm Setup ===
LASTFM_URL = "http://ws.audioscrobbler.com/2.0/"

def get_lyrics(title, artist):
    """Fetch lyrics from Genius API"""
    try:
        song = genius.search_song(title, artist)
        if song:
            return song.lyrics
    except Exception as e:
        print(f"Error fetching lyrics for {title} by {artist}: {e}")
    return None

# %%
def clean_title(title):
    """Remove common extras like (Remastered), feat., etc."""
    title = re.sub(r"\(.*?\)", "", title)  # remove parentheses
    title = re.sub(r"feat\.|ft\.", "", title, flags=re.IGNORECASE)  # remove features
    return title.strip()

def get_genres(title, artist):
    try:
        # First try track-level tags
        params = {
            "method": "track.gettoptags",
            "artist": artist,
            "track": title,
            "api_key": LASTFM_API_KEY,
            "format": "json"
        }
        r = requests.get(LASTFM_URL, params=params)
        data = r.json()

        tags = data.get("toptags", {}).get("tag", [])
        if isinstance(tags, dict):
            tags = [tags]

        if tags:  # track tags found
            return ", ".join([t["name"] for t in tags[:5]])

        # Fallback: try artist-level tags
        params = {
            "method": "artist.gettoptags",
            "artist": artist,
            "api_key": LASTFM_API_KEY,
            "format": "json"
        }
        r = requests.get(LASTFM_URL, params=params)
        data = r.json()

        tags = data.get("toptags", {}).get("tag", [])
        if isinstance(tags, dict):
            tags = [tags]

        if tags:
            return ", ".join([t["name"] for t in tags[:5]])

        return None
    except Exception as e:
        print(f"Error fetching genres for {title} by {artist}: {e}")
        return None

# %%
year = 2012

# %%
while year < 2014:
    lyrics_list = []
    genres_list = []
    df = pd.read_csv(f"billboard-year-end-top100-singles/billboard_{year}.csv")  # columns: title, artist
    for i, row in df.iterrows():
        title, artist = row["Title"], row["Artist(s)"]
    
        # Fetch lyrics
        lyrics = get_lyrics(title, artist)
        lyrics_list.append(lyrics)
    
        # Throttle between Genius and Last.fm
        # time.sleep(1) who needs caution?
    
        # Fetch genres
        genres = get_genres(title, artist)
        genres_list.append(genres)
    
        print(f"Processed: {title} - {artist}")
        time.sleep(1)  # small delay before next song
    
    # Add to DataFrame
    df["lyrics"] = lyrics_list
    df["genres"] = genres_list
    
    # Save enriched CSV
    df.to_csv(f"{year}song_lyrics_and_genres.csv", index=False)
    year += 1
# Out:
# Searching for ""Somebody That I Used to Know"" by Gotye featuring Kimbra...
# Done.
# Processed: "Somebody That I Used to Know" - Gotye featuring Kimbra
# Searching for ""Call Me Maybe"" by Carly Rae Jepsen...
# Done.
# Processed: "Call Me Maybe" - Carly Rae Jepsen
# Searching for ""We Are Young"" by Fun featuring Janelle Monáe...
# Done.
# Processed: "We Are Young" - Fun featuring Janelle Monáe
# Searching for ""Payphone"" by Maroon 5 featuring Wiz Khalifa...
# Done.
# Processed: "Payphone" - Maroon 5 featuring Wiz Khalifa
# Searching for ""Lights"" by Ellie Goulding...
# Done.
# Processed: "Lights" - Ellie Goulding
# Searching for ""Glad You Came"" by The Wanted...
# Done.
# Processed: "Glad You Came" - The Wanted
# Searching for ""Stronger (What Doesn't Kill You)"" by Kelly Clarkson...
# Done.
# Processed: "Stronger (What Doesn't Kill You)" - Kelly Clarkson
# Searching for ""We Found Love"" by Rihanna featuring Calvin Harris...
# Done.
# Processed: "We Found Love" - Rihanna featuring Calvin Harris
# Searching for ""Starships"" by Nicki Minaj...
# Done.
# Processed: "Starships" - Nicki Minaj
# Searching for ""What Makes You Beautiful"" by One Direction...
# Done.
# Processed: "What Makes You Beautiful" - One Direction
# Searching for ""Wild Ones"" by Flo Rida featuring Sia...
# Done.
# Processed: "Wild Ones" - Flo Rida featuring Sia
# Searching for ""Set Fire to the Rain"" by Adele...
# Done.
# Processed: "Set Fire to the Rain" - Adele
# Searching for ""Sexy and I Know It"" by LMFAO...
# Done.
# Processed: "Sexy and I Know It" - LMFAO
# Searching for ""Some Nights"" by Fun...
# Done.
# Processed: "Some Nights" - Fun
# Searching for ""Wide Awake"" by Katy Perry...
# Done.
# Processed: "Wide Awake" - Katy Perry
# Searching for ""Good Feeling"" by Flo Rida...
# Done.
# Processed: "Good Feeling" - Flo Rida
# Searching for ""Whistle"" by Flo Rida...
# Done.
# Processed: "Whistle" - Flo Rida
# Searching for ""One More Night"" by Maroon 5...
# Done.
# Processed: "One More Night" - Maroon 5
# Searching for ""Drive By"" by Train...
# Done.
# Processed: "Drive By" - Train
# Searching for ""The Motto"" by Drake featuring Lil Wayne...
# Done.
# Processed: "The Motto" - Drake featuring Lil Wayne
# Searching for ""Where Have You Been"" by Rihanna...
# Done.
# Processed: "Where Have You Been" - Rihanna
# Searching for ""Everybody Talks"" by Neon Trees...
# Done.
# Processed: "Everybody Talks" - Neon Trees
# Searching for ""Take Care"" by Drake featuring Rihanna...
# Done.
# Processed: "Take Care" - Drake featuring Rihanna
# Searching for ""Titanium"" by David Guetta featuring Sia...
# Done.
# Processed: "Titanium" - David Guetta featuring Sia
# Searching for ""I Won't Give Up"" by Jason Mraz...
# Done.
# Processed: "I Won't Give Up" - Jason Mraz
# Searching for ""It Will Rain"" by Bruno Mars...
# Done.
# Processed: "It Will Rain" - Bruno Mars
# Searching for ""Mercy"" by Kanye West, Big Sean, Pusha T and 2 Chainz...
# Done.
# Processed: "Mercy" - Kanye West, Big Sean, Pusha T and 2 Chainz
# Processed: "Wanted" - Hunter Hayes
# Searching for ""Drunk on You"" by Luke Bryan...
# Done.
# Processed: "Drunk on You" - Luke Bryan
# Searching for ""No Lie"" by 2 Chainz featuring Drake...
# Done.
# Processed: "No Lie" - 2 Chainz featuring Drake
# Searching for ""Want U Back"" by Cher Lloyd...
# Done.
# Processed: "Want U Back" - Cher Lloyd
# Searching for ""Don't Wake Me Up"" by Chris Brown...
# Done.
# Processed: "Don't Wake Me Up" - Chris Brown
# Searching for ""Dance (A$$)"" by Big Sean featuring Nicki Minaj...
# Done.
# Processed: "Dance (A$$)" - Big Sean featuring Nicki Minaj
# Searching for ""Springsteen"" by Eric Church...
# Done.
# Processed: "Springsteen" - Eric Church
# Searching for ""Brokenhearted"" by Karmin...
# Done.
# Processed: "Brokenhearted" - Karmin
# Searching for ""Not Over You"" by Gavin DeGraw...
# Done.
# Processed: "Not Over You" - Gavin DeGraw
# Searching for ""Stereo Hearts"" by Gym Class Heroes featuring Adam Levine...
# Done.
# Processed: "Stereo Hearts" - Gym Class Heroes featuring Adam Levine
# Searching for ""Back in Time"" by Pitbull...
# Done.
# Processed: "Back in Time" - Pitbull
# Searching for ""Work Out"" by J. Cole...
# Done.
# Processed: "Work Out" - J. Cole
# Searching for ""Rumour Has It"" by Adele...
# Done.
# Processed: "Rumour Has It" - Adele
# Searching for ""Let's Go"" by Calvin Harris featuring Ne-Yo...
# Done.
# Processed: "Let's Go" - Calvin Harris featuring Ne-Yo
# Searching for ""Good Girl"" by Carrie Underwood...
# Done.
# Processed: "Good Girl" - Carrie Underwood
# Searching for ""Pontoon"" by Little Big Town...
# Done.
# Processed: "Pontoon" - Little Big Town
# Searching for ""Ho Hey"" by The Lumineers...
# Done.
# Processed: "Ho Hey" - The Lumineers
# Searching for ""Paradise"" by Coldplay...
# Done.
# Processed: "Paradise" - Coldplay
# Searching for ""Blown Away"" by Carrie Underwood...
# Done.
# Processed: "Blown Away" - Carrie Underwood
# Searching for ""Rolling in the Deep"" by Adele...
# Done.
# Processed: "Rolling in the Deep" - Adele
# Searching for ""Climax"" by Usher...
# Done.
# Processed: "Climax" - Usher
# Searching for ""Work Hard, Play Hard"" by Wiz Khalifa...
# Done.
# Processed: "Work Hard, Play Hard" - Wiz Khalifa
# Searching for ""Let Me Love You (Until You Learn to Love Yourself)"" by Ne-Yo...
# Done.
# Processed: "Let Me Love You (Until You Learn to Love Yourself)" - Ne-Yo
# Searching for ""Pound the Alarm"" by Nicki Minaj...
# Done.
# Processed: "Pound the Alarm" - Nicki Minaj
# Searching for ""Come Over"" by Kenny Chesney...
# Done.
# Processed: "Come Over" - Kenny Chesney
# Searching for ""Heart Attack"" by Trey Songz...
# Done.
# Processed: "Heart Attack" - Trey Songz
# Searching for ""Drank in My Cup"" by Kirko Bangz...
# Done.
# Processed: "Drank in My Cup" - Kirko Bangz
# Searching for ""Birthday Cake"" by Rihanna featuring Chris Brown...
# Done.
# Processed: "Birthday Cake" - Rihanna featuring Chris Brown
# Searching for ""So Good"" by B.o.B...
# Done.
# Processed: "So Good" - B.o.B
# Searching for ""50 Ways to Say Goodbye"" by Train...
# Done.
# Processed: "50 Ways to Say Goodbye" - Train
# Searching for ""Red Solo Cup"" by Toby Keith...
# Done.
# Processed: "Red Solo Cup" - Toby Keith
# Searching for ""Love You Like a Love Song"" by Selena Gomez & the Scene...
# Done.
# Processed: "Love You Like a Love Song" - Selena Gomez & the Scene
# Searching for ""Turn Up the Music"" by Chris Brown...
# Done.
# Processed: "Turn Up the Music" - Chris Brown
# Searching for ""Die Young"" by Kesha...
# Done.
# Processed: "Die Young" - Kesha
# Searching for ""5 O'Clock"" by T-Pain featuring Wiz Khalifa and Lily Allen...
# Done.
# Processed: "5 O'Clock" - T-Pain featuring Wiz Khalifa and Lily Allen
# Searching for ""A Thousand Years"" by Christina Perri...
# Done.
# Processed: "A Thousand Years" - Christina Perri
# Searching for ""Take a Little Ride"" by Jason Aldean...
# Done.
# Processed: "Take a Little Ride" - Jason Aldean
# Searching for ""You da One"" by Rihanna...
# Done.
# Processed: "You da One" - Rihanna
# Searching for ""We Run the Night"" by Havana Brown featuring Pitbull...
# Done.
# Processed: "We Run the Night" - Havana Brown featuring Pitbull
# Searching for ""It's Time"" by Imagine Dragons...
# Done.
# Processed: "It's Time" - Imagine Dragons
# Searching for ""Cashin' Out"" by Cash Out...
# Done.
# Processed: "Cashin' Out" - Cash Out
# Searching for ""I Don't Want This Night to End"" by Luke Bryan...
# Done.
# Processed: "I Don't Want This Night to End" - Luke Bryan
# Searching for ""Diamonds"" by Rihanna...
# Done.
# Processed: "Diamonds" - Rihanna
# Searching for ""Hard to Love"" by Lee Brice...
# Done.
# Processed: "Hard to Love" - Lee Brice
# Searching for ""Somethin' 'Bout a Truck"" by Kip Moore...
# Done.
# Processed: "Somethin' 'Bout a Truck" - Kip Moore
# Searching for ""Adorn"" by Miguel...
# Done.
# Processed: "Adorn" - Miguel
# Searching for ""Fly Over States"" by Jason Aldean...
# Done.
# Processed: "Fly Over States" - Jason Aldean
# Searching for ""Even If It Breaks Your Heart"" by Eli Young Band...
# Done.
# Processed: "Even If It Breaks Your Heart" - Eli Young Band
# Searching for ""Burn It Down"" by Linkin Park...
# Done.
# Processed: "Burn It Down" - Linkin Park
# Searching for ""Thrift Shop"" by Macklemore & Ryan Lewis featuring Wanz...
# Done.
# Processed: "Thrift Shop" - Macklemore & Ryan Lewis featuring Wanz
# Searching for ""Blurred Lines"" by Robin Thicke featuring T.I. and Pharrell Williams...
# Done.
# Processed: "Blurred Lines" - Robin Thicke featuring T.I. and Pharrell Williams
# Searching for ""Radioactive"" by Imagine Dragons...
# Done.
# Processed: "Radioactive" - Imagine Dragons
# Searching for ""Harlem Shake"" by Baauer...
# Done.

# HTTPSConnectionPool(host='api.genius.com', port=443): Read timed out. (read timeout=15)
# Processed: "It's Time" - Imagine Dragons
# Searching for ""Power Trip"" by J. Cole featuring Miguel...
# Done.
# Processed: "Power Trip" - J. Cole featuring Miguel
# Searching for ""Girl on Fire"" by Alicia Keys featuring Nicki Minaj...
# Done.
# Processed: "Girl on Fire" - Alicia Keys featuring Nicki Minaj
# Searching for ""Heart Attack"" by Demi Lovato...
# Done.
# Processed: "Heart Attack" - Demi Lovato
# Searching for ""Love Somebody"" by Maroon 5...
# Done.
# Processed: "Love Somebody" - Maroon 5
# Searching for ""I Will Wait"" by Mumford & Sons...
# Done.
# Processed: "I Will Wait" - Mumford & Sons
# Searching for ""Try"" by Pink...
# Done.
# Processed: "Try" - Pink
# Searching for ""Wagon Wheel"" by Darius Rucker...
# Done.
# Processed: "Wagon Wheel" - Darius Rucker
# Searching for ""Gangnam Style"" by Psy...
# Done.
# Processed: "Gangnam Style" - Psy
# Searching for ""I Need Your Love"" by Calvin Harris featuring Ellie Goulding...
# Done.
# Processed: "I Need Your Love" - Calvin Harris featuring Ellie Goulding
# Searching for ""Die Young"" by Kesha...
# Done.
# Processed: "Die Young" - Kesha
# Searching for ""Some Nights"" by Fun...
# Done.
# Processed: "Some Nights" - Fun
# Searching for ""Bad"" by Wale featuring Tiara Thomas or Rihanna...
# No results found for: '"Bad" Wale featuring Tiara Thomas or Rihanna'
# Processed: "Bad" - Wale featuring Tiara Thomas or Rihanna
# Searching for ""Boys 'Round Here"" by Blake Shelton featuring Pistol Annies and Friends...
# No results found for: '"Boys 'Round Here" Blake Shelton featuring Pistol Annies and Friends'
# Processed: "Boys 'Round Here" - Blake Shelton featuring Pistol Annies and Friends
# Searching for ""Gone, Gone, Gone"" by Phillip Phillips...
# Done.
# Processed: "Gone, Gone, Gone" - Phillip Phillips
# Searching for ""Demons"" by Imagine Dragons...
# Done.
# Processed: "Demons" - Imagine Dragons
# Searching for ""Counting Stars"" by OneRepublic...
# Done.
# Processed: "Counting Stars" - OneRepublic
# Searching for ""I Cry"" by Flo Rida...
# Done.
# Processed: "I Cry" - Flo Rida
# Searching for ""Little Talks"" by Of Monsters and Men...
# Done.
# Processed: "Little Talks" - Of Monsters and Men
# Searching for ""The Other Side"" by Jason Derulo...
# Done.
# Processed: "The Other Side" - Jason Derulo
# Searching for ""Berzerk"" by Eminem...
# Done.
# Processed: "Berzerk" - Eminem
# Searching for ""Catch My Breath"" by Kelly Clarkson...
# Done.
# Processed: "Catch My Breath" - Kelly Clarkson
# Searching for ""Crash My Party"" by Luke Bryan...
# Done.
# Processed: "Crash My Party" - Luke Bryan
# Searching for ""Pour It Up"" by Rihanna...
# Done.
# Processed: "Pour It Up" - Rihanna
# Searching for ""22"" by Taylor Swift...
# Done.
# Processed: "22" - Taylor Swift
# Searching for ""I Want Crazy"" by Hunter Hayes...
# Done.
# Processed: "I Want Crazy" - Hunter Hayes
# Searching for ""The Fox (What Does the Fox Say?)"" by Ylvis...
# Done.
# Processed: "The Fox (What Does the Fox Say?)" - Ylvis
# Searching for ""Best Song Ever"" by One Direction...
# Done.
# Processed: "Best Song Ever" - One Direction
# Searching for ""The A Team"" by Ed Sheeran...
# Done.
# Processed: "The A Team" - Ed Sheeran
# Searching for ""Carry On"" by Fun...
# Done.
# Processed: "Carry On" - Fun
# Searching for ""Highway Don't Care"" by Tim McGraw featuring Taylor Swift and Keith Urban...
# Done.
# Processed: "Highway Don't Care" - Tim McGraw featuring Taylor Swift and Keith Urban
# Searching for ""That's My Kind of Night"" by Luke Bryan...
# Done.
# Processed: "That's My Kind of Night" - Luke Bryan
# Searching for ""Swimming Pools (Drank)"" by Kendrick Lamar...
# Done.
# Processed: "Swimming Pools (Drank)" - Kendrick Lamar
# Searching for ""Sure Be Cool If You Did"" by Blake Shelton...
# Done.
# Processed: "Sure Be Cool If You Did" - Blake Shelton
# Searching for ""#Beautiful"" by Mariah Carey featuring Miguel...
# Done.
# Processed: "#Beautiful" - Mariah Carey featuring Miguel
# Searching for ""Troublemaker"" by Olly Murs featuring Flo Rida...
# Done.
# Processed: "Troublemaker" - Olly Murs featuring Flo Rida
# Searching for ""Body Party"" by Ciara...
# Done.
# Processed: "Body Party" - Ciara
# Searching for ""Adorn"" by Miguel...
# Done.
# Processed: "Adorn" - Miguel
# Searching for ""Hall of Fame"" by The Script featuring will.i.am...
# Done.
# Processed: "Hall of Fame" - The Script featuring will.i.am
# Searching for ""Let Me Love You (Until You Learn to Love Yourself)"" by Ne-Yo...
# Done.
# Processed: "Let Me Love You (Until You Learn to Love Yourself)" - Ne-Yo
# Searching for ""U.O.E.N.O."" by Rocko featuring Future and Rick Ross...
# Done.
# Processed: "U.O.E.N.O." - Rocko featuring Future and Rick Ross
# Searching for ""Next to Me"" by Emeli Sandé...
# Done.
# Processed: "Next to Me" - Emeli Sandé
# Searching for ""Mama's Broken Heart"" by Miranda Lambert...
# Done.
# Processed: "Mama's Broken Heart" - Miranda Lambert
# Searching for ""It Goes Like This"" by Thomas Rhett...
# Done.
# Processed: "It Goes Like This" - Thomas Rhett
# Searching for ""Bugatti"" by Ace Hood featuring Future and Rick Ross...
# Done.
# Processed: "Bugatti" - Ace Hood featuring Future and Rick Ross
# Searching for ""Wanted"" by Hunter Hayes...
# Done.
# Processed: "Wanted" - Hunter Hayes
# Searching for ""Downtown"" by Lady Antebellum...
# Done.
# Processed: "Downtown" - Lady Antebellum
# Searching for ""Get Your Shine On"" by Florida Georgia Line...
# Done.
# Processed: "Get Your Shine On" - Florida Georgia Line
# Searching for ""#thatPower"" by will.i.am featuring Justin Bieber...
# Done.
# Processed: "#thatPower" - will.i.am featuring Justin Bieber
# Searching for ""Brave"" by Sara Bareilles...
# Done.
# Processed: "Brave" - Sara Bareilles
# Searching for ""Let Her Go"" by Passenger...
# Done.
# Processed: "Let Her Go" - Passenger
# Searching for ""Runnin' Outta Moonlight"" by Randy Houser...
# Done.
# Processed: "Runnin' Outta Moonlight" - Randy Houser
# Searching for ""I'm Different"" by 2 Chainz...
# Done.
# Processed: "I'm Different" - 2 Chainz
# Searching for ""Still Into You"" by Paramore...
# Done.
# Processed: "Still Into You" - Paramore
