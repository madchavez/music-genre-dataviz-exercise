# %%
import os
from dotenv import load_dotenv
import re
import requests
import pandas as pd
import time
import lyricsgenius
import requests

# %%
load_dotenv()

GENIUS_API_KEY = os.getenv("GENIUS_API")
LASTFM_API_KEY = os.getenv("LASTFM_API")
LASTFM_URL = "http://ws.audioscrobbler.com/2.0/"
print("Using Genius API:", GENIUS_API_KEY[:5] + "*****")  # sanity check
print("Using LastFM API:", LASTFM_API_KEY[:5] + "*****")  # sanity check
# Out:
# Using Genius API: iQe2k*****
# Using LastFM API: fc10b*****

# %%
genius = lyricsgenius.Genius(GENIUS_API_KEY)
genius.timeout = 15
genius.remove_section_headers = True

# === Last.fm Setup ===
LASTFM_URL = "http://ws.audioscrobbler.com/2.0/"

def get_lyrics(title, artist):
    """Fetch lyrics from Genius API"""
    try:
        song = genius.search_song(title, artist)
        if song:
            return song.lyrics
    except Exception as e:
        print(f"Error fetching lyrics for {title} by {artist}: {e}")
    return None

# %%
def clean_title(title):
    """Remove common extras like (Remastered), feat., etc."""
    title = re.sub(r"\(.*?\)", "", title)  # remove parentheses
    title = re.sub(r"feat\.|ft\.", "", title, flags=re.IGNORECASE)  # remove features
    return title.strip()

def get_genres(title, artist):
    try:
        # First try track-level tags
        params = {
            "method": "track.gettoptags",
            "artist": artist,
            "track": title,
            "api_key": LASTFM_API_KEY,
            "format": "json"
        }
        r = requests.get(LASTFM_URL, params=params)
        data = r.json()

        tags = data.get("toptags", {}).get("tag", [])
        if isinstance(tags, dict):
            tags = [tags]

        if tags:  # track tags found
            return ", ".join([t["name"] for t in tags[:5]])

        # Fallback: try artist-level tags
        params = {
            "method": "artist.gettoptags",
            "artist": artist,
            "api_key": LASTFM_API_KEY,
            "format": "json"
        }
        r = requests.get(LASTFM_URL, params=params)
        data = r.json()

        tags = data.get("toptags", {}).get("tag", [])
        if isinstance(tags, dict):
            tags = [tags]

        if tags:
            return ", ".join([t["name"] for t in tags[:5]])

        return None
    except Exception as e:
        print(f"Error fetching genres for {title} by {artist}: {e}")
        return None

# %%
year = 1976

# %%
while year < 2025:
    lyrics_list = []
    genres_list = []
    df = pd.read_csv(f"billboard-year-end-top100-singles/billboard_{year}.csv")  # columns: title, artist
    for i, row in df.iterrows():
        title, artist = row["Title"], row["Artist(s)"]
    
        # Fetch lyrics
        lyrics = get_lyrics(title, artist)
        lyrics_list.append(lyrics)
    
        # Throttle between Genius and Last.fm
        # time.sleep(1) who needs caution?
    
        # Fetch genres
        genres = get_genres(title, artist)
        genres_list.append(genres)
    
        print(f"Processed: {title} - {artist}")
        time.sleep(1)  # small delay before next song
    
    # Add to DataFrame
    df["lyrics"] = lyrics_list
    df["genres"] = genres_list
    
    # Save enriched CSV
    df.to_csv(f"{year}song_lyrics_and_genres.csv", index=False)
    year += 1
# Out:
# Searching for ""Silly Love Songs"" by Wings...
# Done.
# Processed: "Silly Love Songs" - Wings
# Searching for ""Don't Go Breaking My Heart"" by Elton John & Kiki Dee...
# Done.
# Processed: "Don't Go Breaking My Heart" - Elton John & Kiki Dee
# Searching for ""Disco Lady"" by Johnnie Taylor...
# Done.
# Processed: "Disco Lady" - Johnnie Taylor
# Searching for ""December, 1963 (Oh, What a Night)"" by The Four Seasons...
# Done.
# Processed: "December, 1963 (Oh, What a Night)" - The Four Seasons
# Searching for ""Play That Funky Music"" by Wild Cherry...
# Done.
# Processed: "Play That Funky Music" - Wild Cherry
# Searching for ""Kiss and Say Goodbye"" by The Manhattans...
# Done.
# Processed: "Kiss and Say Goodbye" - The Manhattans
# Searching for ""Love Machine"" by The Miracles...
# Done.
# Processed: "Love Machine" - The Miracles
# Searching for ""50 Ways to Leave Your Lover"" by Paul Simon...
# Done.
# Processed: "50 Ways to Leave Your Lover" - Paul Simon
# Searching for ""Love Is Alive"" by Gary Wright...
# Done.
# Processed: "Love Is Alive" - Gary Wright
# Searching for ""A Fifth of Beethoven"" by Walter Murphy & The Big Apple Band...
# Specified song does not contain lyrics. Rejecting.
# Processed: "A Fifth of Beethoven" - Walter Murphy & The Big Apple Band
# Searching for ""Sara Smile"" by Daryl Hall & John Oates...
# Done.
# Processed: "Sara Smile" - Daryl Hall & John Oates
# Searching for ""Afternoon Delight"" by Starland Vocal Band...
# Done.
# Processed: "Afternoon Delight" - Starland Vocal Band
# Searching for ""I Write the Songs"" by Barry Manilow...
# Done.
# Processed: "I Write the Songs" - Barry Manilow
# Searching for ""Fly, Robin, Fly"" by Silver Convention...
# Done.
# Processed: "Fly, Robin, Fly" - Silver Convention
# Searching for ""Love Hangover"" by Diana Ross...
# Done.
# Processed: "Love Hangover" - Diana Ross
# Searching for ""Get Closer"" by Seals and Crofts...
# Done.
# Processed: "Get Closer" - Seals and Crofts
# Searching for ""More, More, More"" by Andrea True Connection...
# Done.
# Processed: "More, More, More" - Andrea True Connection
# Searching for ""Bohemian Rhapsody"" by Queen...
# Done.
# Processed: "Bohemian Rhapsody" - Queen
# Searching for ""Misty Blue"" by Dorothy Moore...
# Done.
# Processed: "Misty Blue" - Dorothy Moore
# Searching for ""Boogie Fever"" by The Sylvers...
# Done.
# Processed: "Boogie Fever" - The Sylvers
# Searching for ""I'd Really Love to See You Tonight"" by England Dan & John Ford Coley...
# Done.
# Processed: "I'd Really Love to See You Tonight" - England Dan & John Ford Coley
# Searching for ""You Sexy Thing"" by Hot Chocolate...
# Done.
# Processed: "You Sexy Thing" - Hot Chocolate
# Searching for ""Love Hurts"" by Nazareth...
# Done.
# Processed: "Love Hurts" - Nazareth
# Searching for ""Get Up and Boogie"" by Silver Convention...
# Done.
# Processed: "Get Up and Boogie" - Silver Convention
# Searching for ""Take It to the Limit"" by Eagles...
# Done.
# Processed: "Take It to the Limit" - Eagles
# Searching for ""(Shake, Shake, Shake) Shake Your Booty"" by KC and the Sunshine Band...
# Done.
# Processed: "(Shake, Shake, Shake) Shake Your Booty" - KC and the Sunshine Band
# Searching for ""Sweet Love"" by Commodores...
# Done.
# Processed: "Sweet Love" - Commodores
# Searching for ""Times of Your Life"" by Paul Anka...
# Done.
# Processed: "Times of Your Life" - Paul Anka
# Searching for ""Devil Woman"" by Cliff Richard...
# Done.
# Processed: "Devil Woman" - Cliff Richard
# Searching for ""Fooled Around and Fell in Love"" by Elvin Bishop...
# Done.
# Processed: "Fooled Around and Fell in Love" - Elvin Bishop
# Searching for ""Convoy"" by C. W. McCall...
# No results found for: '"Convoy" C. W. McCall'
# Processed: "Convoy" - C. W. McCall
# Searching for ""Welcome Back"" by John Sebastian...
# Done.
# Processed: "Welcome Back" - John Sebastian
# Searching for ""Sing a Song"" by Earth, Wind & Fire...
# Done.
# Processed: "Sing a Song" - Earth, Wind & Fire
# Searching for ""Heaven Must Be Missing an Angel"" by Tavares...
# Done.
# Processed: "Heaven Must Be Missing an Angel" - Tavares
# Searching for ""I'll Be Good to You"" by The Brothers Johnson...
# Done.
# Processed: "I'll Be Good to You" - The Brothers Johnson
# Searching for ""Rock and Roll Music"" by The Beach Boys...
# Done.
# Processed: "Rock and Roll Music" - The Beach Boys
# Searching for ""Shop Around"" by Captain & Tennille...
# Done.
# Processed: "Shop Around" - Captain & Tennille
# Searching for ""Saturday Night"" by Bay City Rollers...
# Done.
# Processed: "Saturday Night" - Bay City Rollers
# Searching for ""Island Girl"" by Elton John...
# Done.
# Processed: "Island Girl" - Elton John
# Searching for ""Let's Do It Again"" by The Staple Singers...
# Done.
# Processed: "Let's Do It Again" - The Staple Singers
# Searching for ""Let 'Em In"" by Wings...
# Done.
# Processed: "Let 'Em In" - Wings
# Searching for ""Baby Face"" by Wing and a Prayer Fife and Drum Corps...
# Done.
# Processed: "Baby Face" - Wing and a Prayer Fife and Drum Corps
# Searching for ""This Masquerade"" by George Benson...
# Done.
# Processed: "This Masquerade" - George Benson
# Searching for ""Evil Woman"" by Electric Light Orchestra...
# Done.
# Processed: "Evil Woman" - Electric Light Orchestra
# Searching for ""Wham Bam"" by Silver...
# Done.
# Processed: "Wham Bam" - Silver
# Searching for ""I'm Easy"" by Keith Carradine...
# Done.
# Processed: "I'm Easy" - Keith Carradine
# Searching for ""Wake Up Everybody"" by Harold Melvin & the Blue Notes...
# Done.
# Processed: "Wake Up Everybody" - Harold Melvin & the Blue Notes
# Searching for ""Summer"" by War...
# Done.
# Processed: "Summer" - War
# Searching for ""Let Her In"" by John Travolta...
# Done.
# Processed: "Let Her In" - John Travolta
# Searching for ""Fox on the Run"" by Sweet...
# Done.
# Processed: "Fox on the Run" - Sweet
# Searching for ""Rhiannon"" by Fleetwood Mac...
# Done.
# Processed: "Rhiannon" - Fleetwood Mac
# Searching for ""Got to Get You into My Life"" by The Beatles...
# Done.
# Processed: "Got to Get You into My Life" - The Beatles
# Searching for ""Fanny (Be Tender with My Love)"" by Bee Gees...
# Done.
# Processed: "Fanny (Be Tender with My Love)" - Bee Gees
# Searching for ""Getaway"" by Earth, Wind & Fire...
# Done.
# Processed: "Getaway" - Earth, Wind & Fire
# Processed: "Heard It in a Love Song" - The Marshall Tucker Band
# Searching for ""Carry On Wayward Son"" by Kansas...
# Done.
# Processed: "Carry On Wayward Son" - Kansas
# Searching for ""New Kid in Town"" by Eagles...
# Done.
# Processed: "New Kid in Town" - Eagles
# Searching for ""My Heart Belongs to Me"" by Barbra Streisand...
# Done.
# Processed: "My Heart Belongs to Me" - Barbra Streisand
# Searching for ""After the Lovin'"" by Engelbert Humperdinck...
# Done.
# Processed: "After the Lovin'" - Engelbert Humperdinck
# Searching for ""Jet Airliner"" by Steve Miller Band...
# Done.
# Processed: "Jet Airliner" - Steve Miller Band
# Searching for ""Stand Tall"" by Burton Cummings...
# Done.
# Processed: "Stand Tall" - Burton Cummings
# Searching for ""Way Down"" by Elvis Presley...
# Done.
# Processed: "Way Down" - Elvis Presley
# Searching for ""Weekend in New England"" by Barry Manilow...
# Done.
# Processed: "Weekend in New England" - Barry Manilow
# Searching for ""It Was Almost Like a Song"" by Ronnie Milsap...
# Done.
# Processed: "It Was Almost Like a Song" - Ronnie Milsap
# Searching for ""Smoke from a Distant Fire"" by Sanford-Townsend Band...
# Done.
# Processed: "Smoke from a Distant Fire" - Sanford-Townsend Band
# Searching for ""Cold as Ice"" by Foreigner...
# Done.
# Processed: "Cold as Ice" - Foreigner
# Searching for ""Ariel"" by Dean Friedman...
# Done.
# Processed: "Ariel" - Dean Friedman
# Searching for ""Lost Without Your Love"" by Bread...
# Done.
# Processed: "Lost Without Your Love" - Bread
# Searching for ""Star Wars Theme/Cantina Band"" by Meco...
# Specified song does not contain lyrics. Rejecting.
# Processed: "Star Wars Theme/Cantina Band" - Meco
# Searching for ""Float On"" by The Floaters...
# Done.
# Processed: "Float On" - The Floaters
# Searching for ""Jeans On"" by Lord David Dundas...
# Done.
# Processed: "Jeans On" - Lord David Dundas
# Searching for ""Lido Shuffle"" by Boz Scaggs...
# Done.
# Processed: "Lido Shuffle" - Boz Scaggs
# Searching for ""Keep It Comin' Love"" by KC and the Sunshine Band...
# Done.
# Processed: "Keep It Comin' Love" - KC and the Sunshine Band
# Searching for ""You Made Me Believe in Magic"" by Bay City Rollers...
# Done.
# Processed: "You Made Me Believe in Magic" - Bay City Rollers
# Searching for ""Livin' Thing"" by Electric Light Orchestra...
# Done.
# Processed: "Livin' Thing" - Electric Light Orchestra
# Searching for ""Give a Little Bit"" by Supertramp...
# Done.
# Processed: "Give a Little Bit" - Supertramp
# Searching for ""That's Rock 'n' Roll"" by Shaun Cassidy...
# Done.
# Processed: "That's Rock 'n' Roll" - Shaun Cassidy
# Searching for ""Love So Right"" by Bee Gees...
# Done.
# Processed: "Love So Right" - Bee Gees
# Searching for ""The Rubberband Man"" by The Spinners...
# Done.
# Processed: "The Rubberband Man" - The Spinners
# Searching for ""I Never Cry"" by Alice Cooper...
# Done.
# Processed: "I Never Cry" - Alice Cooper
# Searching for ""Nobody Does It Better"" by Carly Simon...
# Done.
# Processed: "Nobody Does It Better" - Carly Simon
# Done.
# Processed: "Boogie Oogie Oogie" - A Taste of Honey
# Searching for ""Three Times a Lady"" by Commodores...
# Done.
# Processed: "Three Times a Lady" - Commodores
# Searching for ""Grease"" by Frankie Valli...
# Done.
# Processed: "Grease" - Frankie Valli
# Searching for ""I Go Crazy"" by Paul Davis...
# Done.
# Processed: "I Go Crazy" - Paul Davis
# Searching for ""You're the One That I Want"" by John Travolta & Olivia Newton-John...
# Done.
# Processed: "You're the One That I Want" - John Travolta & Olivia Newton-John
# Searching for ""Emotion"" by Samantha Sang...
# Done.
# Processed: "Emotion" - Samantha Sang
# Searching for ""Lay Down Sally"" by Eric Clapton...
# Done.
# Processed: "Lay Down Sally" - Eric Clapton
# Searching for ""Miss You"" by The Rolling Stones...
# Done.
# Processed: "Miss You" - The Rolling Stones
# Searching for ""Just the Way You Are"" by Billy Joel...
# Done.
# Processed: "Just the Way You Are" - Billy Joel
# Searching for ""With a Little Luck"" by Wings...
# Done.
# Processed: "With a Little Luck" - Wings
# Searching for ""If I Can't Have You"" by Yvonne Elliman...
# Done.
# Processed: "If I Can't Have You" - Yvonne Elliman
# Searching for ""Dance, Dance, Dance (Yowsah, Yowsah, Yowsah)"" by Chic...
# Done.
# Processed: "Dance, Dance, Dance (Yowsah, Yowsah, Yowsah)" - Chic
# Searching for ""Feels So Good"" by Chuck Mangione...
# Specified song does not contain lyrics. Rejecting.
# Processed: "Feels So Good" - Chuck Mangione
# Searching for ""Hot Child in the City"" by Nick Gilder...
# Done.
# Processed: "Hot Child in the City" - Nick Gilder
# Searching for ""Love Is Like Oxygen"" by Sweet...
# Done.
# Processed: "Love Is Like Oxygen" - Sweet
# Searching for ""It's a Heartache"" by Bonnie Tyler...
# Done.
# Processed: "It's a Heartache" - Bonnie Tyler
# Searching for ""We Will Rock You" / "We Are the Champions"" by Queen...
# Specified song does not contain lyrics. Rejecting.
# Processed: "We Will Rock You" / "We Are the Champions" - Queen
# Searching for ""Baker Street"" by Gerry Rafferty...
# Done.
# Processed: "Baker Street" - Gerry Rafferty
# Searching for ""Can't Smile Without You"" by Barry Manilow...
# Done.
# Processed: "Can't Smile Without You" - Barry Manilow
# Searching for ""Too Much, Too Little, Too Late"" by Johnny Mathis & Deniece Williams...
# Done.
# Processed: "Too Much, Too Little, Too Late" - Johnny Mathis & Deniece Williams
# Searching for ""Dance With Me"" by Peter Brown...
# Done.
# Processed: "Dance With Me" - Peter Brown
# Searching for ""Two Out of Three Ain't Bad"" by Meat Loaf...
# Done.
# Processed: "Two Out of Three Ain't Bad" - Meat Loaf
# Searching for ""Jack And Jill"" by Raydio...
# Done.
# Processed: "Jack And Jill" - Raydio
# Searching for ""Take a Chance on Me"" by ABBA...
# Done.
# Processed: "Take a Chance on Me" - ABBA
# Searching for ""Sometimes When We Touch"" by Dan Hill...
# Done.
# Processed: "Sometimes When We Touch" - Dan Hill
# Searching for ""Last Dance"" by Donna Summer...
# Done.
# Processed: "Last Dance" - Donna Summer
# Searching for ""Hopelessly Devoted to You"" by Olivia Newton-John...
# Done.
# Processed: "Hopelessly Devoted to You" - Olivia Newton-John
# Searching for ""Hot Blooded"" by Foreigner...
# Done.
# Processed: "Hot Blooded" - Foreigner
# Searching for ""You're in My Heart (The Final Acclaim)"" by Rod Stewart...
# Done.
# Processed: "You're in My Heart (The Final Acclaim)" - Rod Stewart
# Searching for ""The Closer I Get to You"" by Roberta Flack & Donny Hathaway...
# Done.
# Processed: "The Closer I Get to You" - Roberta Flack & Donny Hathaway
# Searching for ""Dust in the Wind"" by Kansas...
# Done.
# Processed: "Dust in the Wind" - Kansas
# Searching for ""Magnet and Steel"" by Walter Egan...
# Done.
# Processed: "Magnet and Steel" - Walter Egan
# Searching for ""Short People"" by Randy Newman...
# Done.
# Processed: "Short People" - Randy Newman
# Searching for ""Use ta Be My Girl"" by The O'Jays...
# Done.
# Processed: "Use ta Be My Girl" - The O'Jays
# Searching for ""Our Love"" by Natalie Cole...
# Done.
# Processed: "Our Love" - Natalie Cole
# Searching for ""Love Will Find a Way"" by Pablo Cruise...
# Done.
# Processed: "Love Will Find a Way" - Pablo Cruise
# Searching for ""An Everlasting Love"" by Andy Gibb...
# Done.
# Processed: "An Everlasting Love" - Andy Gibb
# Searching for ""Love Is in the Air"" by John Paul Young...
# Done.
# Processed: "Love Is in the Air" - John Paul Young
# Searching for ""Goodbye Girl"" by David Gates...
# Done.
# Processed: "Goodbye Girl" - David Gates
# Searching for ""Slip Slidin' Away"" by Paul Simon...
# Done.
# Processed: "Slip Slidin' Away" - Paul Simon
# Searching for ""The Groove Line"" by Heatwave...
# Done.
# Processed: "The Groove Line" - Heatwave
# Searching for ""Thunder Island"" by Jay Ferguson...
# Done.
# Processed: "Thunder Island" - Jay Ferguson
# Searching for ""Imaginary Lover"" by Atlanta Rhythm Section...
# Done.
# Processed: "Imaginary Lover" - Atlanta Rhythm Section
# Searching for ""Still the Same"" by Bob Seger & The Silver Bullet Band...
# Done.
# Processed: "Still the Same" - Bob Seger & The Silver Bullet Band
# Searching for ""My Angel Baby"" by Toby Beau...
# Done.
# Processed: "My Angel Baby" - Toby Beau
# Searching for ""Disco Inferno"" by The Trammps...
# Done.
# Processed: "Disco Inferno" - The Trammps
# Searching for ""On Broadway"" by George Benson...
# Done.
# Processed: "On Broadway" - George Benson
# Searching for ""Come Sail Away"" by Styx...
# Done.
# Processed: "Come Sail Away" - Styx
# Searching for ""(Every Time I Turn Around) Back in Love Again"" by L.T.D....
# Done.
# Processed: "(Every Time I Turn Around) Back in Love Again" - L.T.D.
# Searching for ""This Time I'm in It for Love"" by Player...
# Done.
# Processed: "This Time I'm in It for Love" - Player
# Searching for ""You Belong to Me"" by Carly Simon...
# Done.
# Processed: "You Belong to Me" - Carly Simon
# Searching for ""Here You Come Again"" by Dolly Parton...
# Done.
# Processed: "Here You Come Again" - Dolly Parton
# Searching for ""Blue Bayou"" by Linda Ronstadt...
# Done.
# Processed: "Blue Bayou" - Linda Ronstadt
# Searching for ""Peg"" by Steely Dan...
# Done.
# Processed: "Peg" - Steely Dan
# Searching for ""You Needed Me"" by Anne Murray...
# Done.
# Processed: "You Needed Me" - Anne Murray
# Searching for ""Shame"" by Evelyn "Champagne" King...
# Done.
# Processed: "Shame" - Evelyn "Champagne" King
# Searching for ""Reminiscing"" by Little River Band...
# Done.
# Processed: "Reminiscing" - Little River Band
# Searching for ""Count On Me"" by Jefferson Starship...
# Done.
# Processed: "Count On Me" - Jefferson Starship
# Searching for ""Baby Hold On"" by Eddie Money...
# Done.
# Processed: "Baby Hold On" - Eddie Money
# Searching for ""Hey Deanie"" by Shaun Cassidy...
# Done.
# Processed: "Hey Deanie" - Shaun Cassidy
# Searching for ""Summer Nights"" by John Travolta & Olivia Newton-John...
# Done.
# Processed: "Summer Nights" - John Travolta & Olivia Newton-John
# Searching for ""What's Your Name"" by Lynyrd Skynyrd...
# Done.
# Processed: "What's Your Name" - Lynyrd Skynyrd
# Searching for ""Don't It Make My Brown Eyes Blue"" by Crystal Gayle...
# Done.
# Processed: "Don't It Make My Brown Eyes Blue" - Crystal Gayle
# Searching for ""Because the Night"" by Patti Smith Group...
# Done.
# Processed: "Because the Night" - Patti Smith Group
# Searching for ""Every Kinda People"" by Robert Palmer...
# Done.
# Processed: "Every Kinda People" - Robert Palmer
# Searching for ""Copacabana"" by Barry Manilow...
# Done.
# Processed: "Copacabana" - Barry Manilow
# Searching for ""Always and Forever"" by Heatwave...
# Done.
# Processed: "Always and Forever" - Heatwave
# Searching for ""You and I"" by Rick James...
# Done.
# Processed: "You and I" - Rick James
# Searching for ""Serpentine Fire"" by Earth, Wind & Fire...
# Done.
# Processed: "Serpentine Fire" - Earth, Wind & Fire
# Searching for ""Sentimental Lady"" by Bob Welch...
# Done.
# Processed: "Sentimental Lady" - Bob Welch
# Searching for ""Falling"" by LeBlanc & Carr...
# Done.
# Processed: "Falling" - LeBlanc & Carr
# Searching for ""Don't Let Me Be Misunderstood"" by Santa Esmeralda...
# Done.
# Processed: "Don't Let Me Be Misunderstood" - Santa Esmeralda
# Searching for ""Bluer Than Blue"" by Michael Johnson...
# Done.
# Processed: "Bluer Than Blue" - Michael Johnson
# Searching for ""Running on Empty"" by Jackson Browne...
# Done.
# Processed: "Running on Empty" - Jackson Browne
# Searching for ""Whenever I Call You 'Friend'"" by Kenny Loggins & Stevie Nicks...
# Done.
# Processed: "Whenever I Call You 'Friend'" - Kenny Loggins & Stevie Nicks
# Searching for ""Fool (If You Think It's Over)"" by Chris Rea...
# Done.
# Processed: "Fool (If You Think It's Over)" - Chris Rea
# Searching for ""Get Off"" by Foxy...
# Done.
# Processed: "Get Off" - Foxy
# Searching for ""Sweet Talkin' Woman"" by Electric Light Orchestra...
# Done.
# Processed: "Sweet Talkin' Woman" - Electric Light Orchestra
# Searching for ""Life's Been Good"" by Joe Walsh...
# Done.
# Processed: "Life's Been Good" - Joe Walsh
# Searching for ""I Love the Nightlife"" by Alicia Bridges...
# Done.
# Processed: "I Love the Nightlife" - Alicia Bridges
# Searching for ""You Can't Turn Me Off (In The Middle Of Turning Me On)"" by High Inergy...
# Done.
# Processed: "You Can't Turn Me Off (In The Middle Of Turning Me On)" - High Inergy
# Searching for ""It's So Easy"" by Linda Ronstadt...
# Done.
# Processed: "It's So Easy" - Linda Ronstadt
# Searching for ""Native New Yorker"" by Odyssey...
# Done.
# Processed: "Native New Yorker" - Odyssey
# Searching for ""Flash Light"" by Parliament...
# Done.
# Processed: "Flash Light" - Parliament
# Searching for ""Don't Look Back"" by Boston...
# Done.
# Processed: "Don't Look Back" - Boston
# Searching for ""Turn to Stone"" by Electric Light Orchestra...
# Done.
# Processed: "Turn to Stone" - Electric Light Orchestra
# Searching for ""I Can't Stand the Rain"" by Eruption...
# Done.
# Processed: "I Can't Stand the Rain" - Eruption
# Searching for ""Ebony Eyes"" by Bob Welch...
# Done.
# Processed: "Ebony Eyes" - Bob Welch
# Searching for ""The Name of the Game"" by ABBA...
# Done.
# Processed: "The Name of the Game" - ABBA
# Searching for ""We're All Alone"" by Rita Coolidge...
# Done.
# Processed: "We're All Alone" - Rita Coolidge
# Searching for ""Hollywood Nights"" by Bob Seger & The Silver Bullet Band...
# Done.
# Processed: "Hollywood Nights" - Bob Seger & The Silver Bullet Band
# Searching for ""Deacon Blues"" by Steely Dan...
# Done.
# Processed: "Deacon Blues" - Steely Dan
# Searching for ""My Sharona"" by The Knack...
# Done.
# Processed: "My Sharona" - The Knack
# Searching for ""Bad Girls"" by Donna Summer...
# Done.
# Processed: "Bad Girls" - Donna Summer
# Searching for ""Le Freak"" by Chic...
# Done.
# Processed: "Le Freak" - Chic
# Searching for ""Da Ya Think I'm Sexy?"" by Rod Stewart...
# Done.
# Processed: "Da Ya Think I'm Sexy?" - Rod Stewart
# Searching for ""Reunited"" by Peaches & Herb...
# Done.
# Processed: "Reunited" - Peaches & Herb
# Searching for ""I Will Survive"" by Gloria Gaynor...
# Done.
# Processed: "I Will Survive" - Gloria Gaynor
# Searching for ""Hot Stuff"" by Donna Summer...
# Done.
# Processed: "Hot Stuff" - Donna Summer
# Searching for ""Y.M.C.A."" by Village People...
# Done.
# Processed: "Y.M.C.A." - Village People
# Searching for ""Ring My Bell"" by Anita Ward...
# Done.
# Processed: "Ring My Bell" - Anita Ward
# Searching for ""Sad Eyes"" by Robert John...
# Done.
# Processed: "Sad Eyes" - Robert John
# Searching for ""Too Much Heaven"" by Bee Gees...
# Done.
# Processed: "Too Much Heaven" - Bee Gees
# Searching for ""MacArthur Park"" by Donna Summer...
# Done.
# Processed: "MacArthur Park" - Donna Summer
# Searching for ""When You're in Love with a Beautiful Woman"" by Dr. Hook...
# Done.
# Processed: "When You're in Love with a Beautiful Woman" - Dr. Hook
# Searching for ""Makin' It"" by David Naughton...
# Done.
# Processed: "Makin' It" - David Naughton
# Searching for ""Renegade"" by Styx...
# Done.
# Processed: "Renegade" - Styx
# Searching for ""Love Is the Answer"" by England Dan & John Ford Coley...
# Done.
# Processed: "Love Is the Answer" - England Dan & John Ford Coley
# Searching for ""Got to Be Real"" by Cheryl Lynn...
# Done.
# Processed: "Got to Be Real" - Cheryl Lynn
# Searching for ""Born to Be Alive"" by Patrick Hernandez...
# Done.
# Processed: "Born to Be Alive" - Patrick Hernandez
# Searching for ""Shine a Little Love"" by Electric Light Orchestra...
# Done.
# Processed: "Shine a Little Love" - Electric Light Orchestra
# Searching for ""I Just Fall in Love Again"" by Anne Murray...
# Done.
# Processed: "I Just Fall in Love Again" - Anne Murray
# Searching for ""Shake It"" by Ian Matthews...
# Done.
# Processed: "Shake It" - Ian Matthews
# Searching for ""I Was Made for Lovin' You"" by Kiss...
# Done.
# Processed: "I Was Made for Lovin' You" - Kiss
# Searching for ""I Just Wanna Stop"" by Gino Vannelli...
# Done.
# Processed: "I Just Wanna Stop" - Gino Vannelli
# Searching for ""Disco Nights (Rock-Freak)"" by GQ...
# Done.
# Processed: "Disco Nights (Rock-Freak)" - GQ
# Searching for ""Ooo Baby Baby"" by Linda Ronstadt...
# Done.
# Processed: "Ooo Baby Baby" - Linda Ronstadt
# Searching for ""September"" by Earth, Wind & Fire...
# Done.
# Processed: "September" - Earth, Wind & Fire
# Searching for ""Time Passages"" by Al Stewart...
# Done.
# Processed: "Time Passages" - Al Stewart
# Searching for ""Rise"" by Herb Alpert...
# Specified song does not contain lyrics. Rejecting.
# Processed: "Rise" - Herb Alpert
# Searching for ""Don't Bring Me Down"" by Electric Light Orchestra...
# Done.
# Processed: "Don't Bring Me Down" - Electric Light Orchestra
# Searching for ""Promises"" by Eric Clapton...
# Done.
# Processed: "Promises" - Eric Clapton
# Searching for ""Get Used to It"" by Roger Voudouris...
# Done.
# Processed: "Get Used to It" - Roger Voudouris
# Searching for ""How Much I Feel"" by Ambrosia...
# Done.
# Processed: "How Much I Feel" - Ambrosia
# Searching for ""Suspicions"" by Eddie Rabbitt...
# Done.
# Processed: "Suspicions" - Eddie Rabbitt
# Searching for ""You Take My Breath Away"" by Rex Smith...
# Done.
# Processed: "You Take My Breath Away" - Rex Smith
# Searching for ""How You Gonna See Me Now"" by Alice Cooper...
# Done.
# Processed: "How You Gonna See Me Now" - Alice Cooper
# Searching for ""Double Vision"" by Foreigner...
# Done.
# Processed: "Double Vision" - Foreigner
# Searching for ""Everytime I Think of You"" by The Babys...
# Done.
# Processed: "Everytime I Think of You" - The Babys
# Searching for ""I Got My Mind Made Up (You Can Get It Girl)"" by Instant Funk...
# Done.
# Processed: "I Got My Mind Made Up (You Can Get It Girl)" - Instant Funk
# Searching for ""Don't Stop 'til You Get Enough"" by Michael Jackson...
# Done.
# Processed: "Don't Stop 'til You Get Enough" - Michael Jackson
# Searching for ""Bad Case of Loving You (Doctor, Doctor)"" by Robert Palmer...
# Done.
# Processed: "Bad Case of Loving You (Doctor, Doctor)" - Robert Palmer
# Searching for ""Somewhere in the Night"" by Barry Manilow...
# Done.
# Processed: "Somewhere in the Night" - Barry Manilow
# Searching for ""We've Got Tonight"" by Bob Seger & The Silver Bullet Band...
# Done.
# Processed: "We've Got Tonight" - Bob Seger & The Silver Bullet Band
# Searching for ""Dance the Night Away"" by Van Halen...
# Done.
# Processed: "Dance the Night Away" - Van Halen
# Searching for ""Dancin' Shoes"" by Nigel Olsson...
# Done.
# Processed: "Dancin' Shoes" - Nigel Olsson
# Searching for ""The Boss"" by Diana Ross...
# Done.
# Processed: "The Boss" - Diana Ross
# Searching for ""Sail On"" by Commodores...
# Done.
# Processed: "Sail On" - Commodores
# Searching for ""I Do Love You"" by GQ...
# Done.
# Processed: "I Do Love You" - GQ
# Searching for ""Strange Way"" by Firefall...
# Done.
# Processed: "Strange Way" - Firefall
# Searching for ""Call Me"" by Blondie...
# Done.
# Processed: "Call Me" - Blondie
# Searching for ""Another Brick in the Wall, Part II"" by Pink Floyd...
# Done.
# Processed: "Another Brick in the Wall, Part II" - Pink Floyd
# Searching for ""Magic"" by Olivia Newton-John...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 9
#       6 title, artist = row["Title"], row["Artist(s)"]
#       8 # Fetch lyrics
# ----> 9 lyrics = get_lyrics(title, artist)
#      10 lyrics_list.append(lyrics)
#      12 # Throttle between Genius and Last.fm
#      13 # time.sleep(1) who needs caution?
#      14
#      15 # Fetch genres
#
# Cell In[3], line 11, in get_lyrics(title, artist)
#       9 """Fetch lyrics from Genius API"""
#      10 try:
# ---> 11     song = genius.search_song(title, artist)
#      12     if song:
#      13         return song.lyrics
#
# File ~\AppData\Roaming\Python\Python313\site-packages\lyricsgenius\genius.py:490, in Genius.search_song(self, title, artist, song_id, get_full_info)
#     488 # Download full song info (an API call) unless told not to by user
#     489 if song_id is None and get_full_info:
# --> 490     song_info.update(self.song(song_info["id"])["song"])
#     492 if song_info["lyrics_state"] == "complete" and not song_info.get(
#     493     "instrumental"
#     494 ):
#     495     lyrics = self.lyrics(song_url=song_info["url"])
#
# File ~\AppData\Roaming\Python\Python313\site-packages\lyricsgenius\api\api.py:508, in API.song(self, song_id, text_format)
#     485 def song(
#     486     self,
#     487     song_id: int,
#     488     text_format: TextFormatT | None = None,
#     489 ) -> dict[str, Any]:
#     490     """Gets data for a specific song.
#     491
#     492     Args:
#    (...)
#     506
#     507     """
# --> 508     return self._make_request(
#     509         path=f"songs/{song_id}",
#     510         params_={"text_format": text_format or self.response_format},
#     511     )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\lyricsgenius\api\base.py:88, in Sender._make_request(self, path, method, params_, public_api, web, **kwargs)
#      86 tries += 1
#      87 try:
# ---> 88     response = self._session.request(
#      89         method,
#      90         uri,
#      91         timeout=self.timeout,
#      92         params=params_,
#      93         headers=header,
#      94         **kwargs,
#      95     )
#      96 except Timeout as e:
#      97     error = f"Request timed out:\n{e}"
#
# File C:\ProgramData\anaconda3\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File C:\ProgramData\anaconda3\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File C:\ProgramData\anaconda3\Lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File C:\ProgramData\anaconda3\Lib\site-packages\urllib3\connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\urllib3\connection.py:516, in HTTPConnection.getresponse(self)
#     513 _shutdown = getattr(self.sock, "shutdown", None)
#     515 # Get the response from http.client.HTTPConnection
# --> 516 httplib_response = super().getresponse()
#     518 try:
#     519     assert_header_parsing(httplib_response.msg)
#
# File C:\ProgramData\anaconda3\Lib\http\client.py:1430, in HTTPConnection.getresponse(self)
#    1428 try:
#    1429     try:
# -> 1430         response.begin()
#    1431     except ConnectionError:
#    1432         self.close()
#
# File C:\ProgramData\anaconda3\Lib\http\client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File C:\ProgramData\anaconda3\Lib\http\client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File C:\ProgramData\anaconda3\Lib\socket.py:719, in SocketIO.readinto(self, b)
#     717     raise OSError("cannot read from timed out object")
#     718 try:
# --> 719     return self._sock.recv_into(b)
#     720 except timeout:
#     721     self._timeout_occurred = True
#
# File C:\ProgramData\anaconda3\Lib\ssl.py:1304, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1300     if flags != 0:
#    1301         raise ValueError(
#    1302           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1303           self.__class__)
# -> 1304     return self.read(nbytes, buffer)
#    1305 else:
#    1306     return super().recv_into(buffer, nbytes, flags)
#
# File C:\ProgramData\anaconda3\Lib\ssl.py:1138, in SSLSocket.read(self, len, buffer)
#    1136 try:
#    1137     if buffer is not None:
# -> 1138         return self._sslobj.read(len, buffer)
#    1139     else:
#    1140         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
print(df[]
# Out:
# {'toptags': {'tag': [], '@attr': {'artist': 'Carl Douglas', 'track': 'Kung Fu Fighting'}}}
