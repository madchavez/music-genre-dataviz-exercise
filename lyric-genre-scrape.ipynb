# %%
import os
from dotenv import load_dotenv
import re
import requests
import pandas as pd
import time
import lyricsgenius
import requests

# %%
load_dotenv()

GENIUS_API_KEY = os.getenv("GENIUS_API")
LASTFM_API_KEY = os.getenv("LASTFM_API")
LASTFM_URL = "http://ws.audioscrobbler.com/2.0/"
print("Using Genius API:", GENIUS_API_KEY[:5] + "*****")  # sanity check
print("Using LastFM API:", LASTFM_API_KEY[:5] + "*****")  # sanity check
# Out:
# Using Genius API: iQe2k*****
# Using LastFM API: fc10b*****

# %%
genius = lyricsgenius.Genius(GENIUS_API_KEY)
genius.timeout = 15
genius.remove_section_headers = True

# === Last.fm Setup ===
LASTFM_URL = "http://ws.audioscrobbler.com/2.0/"

def get_lyrics(title, artist):
    """Fetch lyrics from Genius API"""
    try:
        song = genius.search_song(title, artist)
        if song:
            return song.lyrics
    except Exception as e:
        print(f"Error fetching lyrics for {title} by {artist}: {e}")
    return None

# %%
def clean_title(title):
    """Remove common extras like (Remastered), feat., etc."""
    title = re.sub(r"\(.*?\)", "", title)  # remove parentheses
    title = re.sub(r"feat\.|ft\.", "", title, flags=re.IGNORECASE)  # remove features
    return title.strip()

def get_genres(title, artist):
    try:
        # First try track-level tags
        params = {
            "method": "track.gettoptags",
            "artist": artist,
            "track": title,
            "api_key": LASTFM_API_KEY,
            "format": "json"
        }
        r = requests.get(LASTFM_URL, params=params)
        data = r.json()

        tags = data.get("toptags", {}).get("tag", [])
        if isinstance(tags, dict):
            tags = [tags]

        if tags:  # track tags found
            return ", ".join([t["name"] for t in tags[:5]])

        # Fallback: try artist-level tags
        params = {
            "method": "artist.gettoptags",
            "artist": artist,
            "api_key": LASTFM_API_KEY,
            "format": "json"
        }
        r = requests.get(LASTFM_URL, params=params)
        data = r.json()

        tags = data.get("toptags", {}).get("tag", [])
        if isinstance(tags, dict):
            tags = [tags]

        if tags:
            return ", ".join([t["name"] for t in tags[:5]])

        return None
    except Exception as e:
        print(f"Error fetching genres for {title} by {artist}: {e}")
        return None

# %%
year = 1980

# %%
while year < 2025:
    lyrics_list = []
    genres_list = []
    df = pd.read_csv(f"billboard-year-end-top100-singles/billboard_{year}.csv")  # columns: title, artist
    for i, row in df.iterrows():
        title, artist = row["Title"], row["Artist(s)"]
    
        # Fetch lyrics
        lyrics = get_lyrics(title, artist)
        lyrics_list.append(lyrics)
    
        # Throttle between Genius and Last.fm
        # time.sleep(1) who needs caution?
    
        # Fetch genres
        genres = get_genres(title, artist)
        genres_list.append(genres)
    
        print(f"Processed: {title} - {artist}")
        time.sleep(1)  # small delay before next song
    
    # Add to DataFrame
    df["lyrics"] = lyrics_list
    df["genres"] = genres_list
    
    # Save enriched CSV
    df.to_csv(f"{year}song_lyrics_and_genres.csv", index=False)
    year += 1
# Out:
# Searching for ""Call Me"" by Blondie...
# Done.
# Processed: "Call Me" - Blondie
# Searching for ""Another Brick in the Wall, Part II"" by Pink Floyd...
# Done.
# Processed: "Another Brick in the Wall, Part II" - Pink Floyd
# Searching for ""Magic"" by Olivia Newton-John...
# Done.
# Processed: "Magic" - Olivia Newton-John
# Searching for ""Rock with You"" by Michael Jackson...
# Done.
# Processed: "Rock with You" - Michael Jackson
# Searching for ""Do That to Me One More Time"" by Captain & Tennille...
# Done.
# Processed: "Do That to Me One More Time" - Captain & Tennille
# Searching for ""Crazy Little Thing Called Love"" by Queen...
# Done.
# Processed: "Crazy Little Thing Called Love" - Queen
# Searching for ""Coming Up"" by Paul McCartney...
# Done.
# Processed: "Coming Up" - Paul McCartney
# Searching for ""Funkytown"" by Lipps Inc....
# Done.
# Processed: "Funkytown" - Lipps Inc.
# Searching for ""It's Still Rock and Roll to Me"" by Billy Joel...
# Done.
# Processed: "It's Still Rock and Roll to Me" - Billy Joel
# Searching for ""The Rose"" by Bette Midler...
# Done.
# Processed: "The Rose" - Bette Midler
# Searching for ""Escape (The Piña Colada Song)"" by Rupert Holmes...
# Done.
# Processed: "Escape (The Piña Colada Song)" - Rupert Holmes
# Searching for ""Cars"" by Gary Numan...
# Done.
# Processed: "Cars" - Gary Numan
# Searching for ""Cruisin"" by Smokey Robinson...
# Done.
# Processed: "Cruisin" - Smokey Robinson
# Searching for ""Working My Way Back to You/Forgive Me, Girl"" by The Spinners...
# No results found for: '"Working My Way Back to You/Forgive Me, Girl" The Spinners'
# Processed: "Working My Way Back to You/Forgive Me, Girl" - The Spinners
# Searching for ""Lost in Love"" by Air Supply...
# Done.
# Processed: "Lost in Love" - Air Supply
# Searching for ""Little Jeannie"" by Elton John...
# Done.
# Processed: "Little Jeannie" - Elton John
# Searching for ""Ride Like the Wind"" by Christopher Cross...
# Done.
# Processed: "Ride Like the Wind" - Christopher Cross
# Searching for ""Upside Down"" by Diana Ross...
# Done.
# Processed: "Upside Down" - Diana Ross
# Searching for ""Please Don't Go"" by KC and the Sunshine Band...
# Done.
# Processed: "Please Don't Go" - KC and the Sunshine Band
# Searching for ""Babe"" by Styx...
# Done.
# Processed: "Babe" - Styx
# Searching for ""With You I'm Born Again"" by Billy Preston and Syreeta...
# Done.
# Processed: "With You I'm Born Again" - Billy Preston and Syreeta
# Searching for ""Shining Star"" by The Manhattans...
# Done.
# Processed: "Shining Star" - The Manhattans
# Searching for ""Still"" by Commodores...
# Done.
# Processed: "Still" - Commodores
# Searching for ""Yes, I'm Ready"" by Teri DeSario & KC...
# Done.
# Processed: "Yes, I'm Ready" - Teri DeSario & KC
# Searching for ""Sexy Eyes"" by Dr. Hook...
# Done.
# Processed: "Sexy Eyes" - Dr. Hook
# Searching for ""Steal Away"" by Robbie Dupree...
# Done.
# Processed: "Steal Away" - Robbie Dupree
# Searching for ""Biggest Part of Me"" by Ambrosia...
# Done.
# Processed: "Biggest Part of Me" - Ambrosia
# Searching for ""This Is It"" by Kenny Loggins...
# Done.
# Processed: "This Is It" - Kenny Loggins
# Searching for ""Cupid/I've Loved You for a Long Time"" by The Spinners...
# Done.
# Processed: "Cupid/I've Loved You for a Long Time" - The Spinners
# Searching for ""Let's Get Serious"" by Jermaine Jackson...
# Done.
# Processed: "Let's Get Serious" - Jermaine Jackson
# Searching for ""Don't Fall in Love with a Dreamer"" by Kenny Rogers & Kim Carnes...
# Done.
# Processed: "Don't Fall in Love with a Dreamer" - Kenny Rogers & Kim Carnes
# Searching for ""Sailing"" by Christopher Cross...
# Done.
# Processed: "Sailing" - Christopher Cross
# Searching for ""Longer"" by Dan Fogelberg...
# Done.
# Processed: "Longer" - Dan Fogelberg
# Searching for ""Coward of the County"" by Kenny Rogers...
# Done.
# Processed: "Coward of the County" - Kenny Rogers
# Searching for ""Ladies' Night"" by Kool & the Gang...
# Done.
# Processed: "Ladies' Night" - Kool & the Gang
# Searching for ""Too Hot"" by Kool & the Gang...
# Done.
# Processed: "Too Hot" - Kool & the Gang
# Searching for ""Take Your Time (Do It Right)"" by The S.O.S. Band...
# Done.
# Processed: "Take Your Time (Do It Right)" - The S.O.S. Band
# Searching for ""No More Tears (Enough Is Enough)"" by Barbra Streisand & Donna Summer...
# Done.
# Processed: "No More Tears (Enough Is Enough)" - Barbra Streisand & Donna Summer
# Searching for ""More Love"" by Kim Carnes...
# Done.
# Processed: "More Love" - Kim Carnes
# Searching for ""Pop Muzik"" by M...
# Done.
# Processed: "Pop Muzik" - M
# Searching for ""Brass in Pocket"" by The Pretenders...
# No results found for: '"Brass in Pocket" The Pretenders'
# Processed: "Brass in Pocket" - The Pretenders
# Searching for ""Special Lady"" by Ray, Goodman & Brown...
# Done.
# Processed: "Special Lady" - Ray, Goodman & Brown
# Searching for ""Send One Your Love"" by Stevie Wonder...
# Done.
# Processed: "Send One Your Love" - Stevie Wonder
# Searching for ""The Second Time Around"" by Shalamar...
# Done.
# Processed: "The Second Time Around" - Shalamar
# Searching for ""We Don't Talk Anymore"" by Cliff Richard...
# Done.
# Processed: "We Don't Talk Anymore" - Cliff Richard
# Searching for ""Stomp!"" by The Brothers Johnson...
# Done.
# Processed: "Stomp!" - The Brothers Johnson
# Searching for ""Heartache Tonight"" by Eagles...
# Done.
# Processed: "Heartache Tonight" - Eagles
# Searching for ""Tired of Toein' the Line"" by Rocky Burnette...
# Done.
# Processed: "Tired of Toein' the Line" - Rocky Burnette
# Searching for ""Better Love Next Time"" by Dr. Hook...
# Done.
# Processed: "Better Love Next Time" - Dr. Hook
# Searching for ""Him"" by Rupert Holmes...
# Done.
# Processed: "Him" - Rupert Holmes
# Searching for ""Against the Wind"" by Bob Seger and the Silver Bullet Band...
# Done.
# Processed: "Against the Wind" - Bob Seger and the Silver Bullet Band
# Searching for ""On the Radio"" by Donna Summer...
# Done.
# Processed: "On the Radio" - Donna Summer
# Searching for ""Emotional Rescue"" by The Rolling Stones...
# Done.
# Processed: "Emotional Rescue" - The Rolling Stones
# Searching for ""Rise"" by Herb Alpert...
# Specified song does not contain lyrics. Rejecting.
# Processed: "Rise" - Herb Alpert
# Searching for ""All Out of Love"" by Air Supply...
# Done.
# Processed: "All Out of Love" - Air Supply
# Searching for ""Cool Change"" by Little River Band...
# Done.
# Processed: "Cool Change" - Little River Band
# Searching for ""You're Only Lonely"" by JD Souther...
# Done.
# Processed: "You're Only Lonely" - JD Souther
# Searching for ""Desire"" by Andy Gibb...
# Done.
# Processed: "Desire" - Andy Gibb
# Searching for ""Let My Love Open the Door"" by Pete Townshend...
# Done.
# Processed: "Let My Love Open the Door" - Pete Townshend
# Searching for ""Romeo's Tune"" by Steve Forbert...
# Done.
# Processed: "Romeo's Tune" - Steve Forbert
# Searching for ""Daydream Believer"" by Anne Murray...
# Done.
# Processed: "Daydream Believer" - Anne Murray
# Searching for ""I Can't Tell You Why"" by Eagles...
# Done.
# Processed: "I Can't Tell You Why" - Eagles
# Searching for ""Don't Let Go"" by Isaac Hayes...
# Done.
# Processed: "Don't Let Go" - Isaac Hayes
# Searching for ""Don't Do Me Like That"" by Tom Petty and the Heartbreakers...
# Done.
# Processed: "Don't Do Me Like That" - Tom Petty and the Heartbreakers
# Searching for ""She's Out of My Life"" by Michael Jackson...
# Done.
# Processed: "She's Out of My Life" - Michael Jackson
# Searching for ""Fame"" by Irene Cara...
# Done.
# Processed: "Fame" - Irene Cara
# Searching for ""Fire Lake"" by Bob Seger and the Silver Bullet Band...
# Done.
# Processed: "Fire Lake" - Bob Seger and the Silver Bullet Band
# Searching for ""How Do I Make You"" by Linda Ronstadt...
# Done.
# Processed: "How Do I Make You" - Linda Ronstadt
# Searching for ""Into the Night"" by Benny Mardones...
# Done.
# Processed: "Into the Night" - Benny Mardones
# Searching for ""Let Me Love You Tonight"" by Pure Prairie League...
# Done.
# Processed: "Let Me Love You Tonight" - Pure Prairie League
# Searching for ""Misunderstanding"" by Genesis...
# Done.
# Processed: "Misunderstanding" - Genesis
# Searching for ""An American Dream"" by The Dirt Band...
# Done.
# Processed: "An American Dream" - The Dirt Band
# Searching for ""One Fine Day"" by Carole King...
# Done.
# Processed: "One Fine Day" - Carole King
# Searching for ""Dim All the Lights"" by Donna Summer...
# Done.
# Processed: "Dim All the Lights" - Donna Summer
# Searching for ""You May Be Right"" by Billy Joel...
# Done.
# Processed: "You May Be Right" - Billy Joel
# Searching for ""Should've Never Let You Go"" by Neil & Dara Sedaka...
# Done.
# Processed: "Should've Never Let You Go" - Neil & Dara Sedaka
# Searching for ""Pilot of the Airwaves"" by Charlie Dore...
# Done.
# Processed: "Pilot of the Airwaves" - Charlie Dore
# Searching for ""Hurt So Bad"" by Linda Ronstadt...
# Done.
# Processed: "Hurt So Bad" - Linda Ronstadt
# Searching for ""Off the Wall"" by Michael Jackson...
# Done.
# Processed: "Off the Wall" - Michael Jackson
# Searching for ""I Pledge My Love"" by Peaches & Herb...
# Done.
# Processed: "I Pledge My Love" - Peaches & Herb
# Searching for ""The Long Run"" by Eagles...
# Done.
# Processed: "The Long Run" - Eagles
# Searching for ""Stand by Me"" by Mickey Gilley...
# Done.
# Processed: "Stand by Me" - Mickey Gilley
# Searching for ""Heartbreaker"" by Pat Benatar...
# Done.
# Processed: "Heartbreaker" - Pat Benatar
# Searching for ""Déjà Vu"" by Dionne Warwick...
# Done.
# Processed: "Déjà Vu" - Dionne Warwick
# Searching for ""Drivin' My Life Away"" by Eddie Rabbitt...
# Done.
# Processed: "Drivin' My Life Away" - Eddie Rabbitt
# Searching for ""Take the Long Way Home"" by Supertramp...
# Done.
# Processed: "Take the Long Way Home" - Supertramp
# Searching for ""Sara"" by Fleetwood Mac...
# Done.
# Processed: "Sara" - Fleetwood Mac
# Searching for ""Wait for Me"" by Daryl Hall & John Oates...
# Done.
# Processed: "Wait for Me" - Daryl Hall & John Oates
# Searching for ""Jojo"" by Boz Scaggs...
# Done.
# Processed: "Jojo" - Boz Scaggs
# Searching for ""September Morn"" by Neil Diamond...
# Done.
# Processed: "September Morn" - Neil Diamond
# Searching for ""Give Me the Night"" by George Benson...
# Done.
# Processed: "Give Me the Night" - George Benson
# Searching for ""Broken Hearted Me"" by Anne Murray...
# Done.
# Processed: "Broken Hearted Me" - Anne Murray
# Searching for ""You Decorated My Life"" by Kenny Rogers...
# Done.
# Processed: "You Decorated My Life" - Kenny Rogers
# Searching for ""Tusk"" by Fleetwood Mac...
# Done.
# Processed: "Tusk" - Fleetwood Mac
# Searching for ""I Wanna Be Your Lover"" by Prince...
# Done.
# Processed: "I Wanna Be Your Lover" - Prince
# Searching for ""In America"" by Charlie Daniels Band...
# Done.
# Processed: "In America" - Charlie Daniels Band
# Searching for ""Breakdown Dead Ahead"" by Boz Scaggs...
# Done.
# Processed: "Breakdown Dead Ahead" - Boz Scaggs
# Searching for ""Ships"" by Barry Manilow...
# Done.
# Processed: "Ships" - Barry Manilow
# Searching for ""All Night Long"" by Joe Walsh...
# Done.
# Processed: "All Night Long" - Joe Walsh
# Searching for ""Refugee"" by Tom Petty and the Heartbreakers...
# Done.
# Processed: "Refugee" - Tom Petty and the Heartbreakers
# Searching for ""Bette Davis Eyes"" by Kim Carnes...
# Done.
# Processed: "Bette Davis Eyes" - Kim Carnes
# Searching for ""Endless Love"" by Diana Ross & Lionel Richie...
# Done.
# Processed: "Endless Love" - Diana Ross & Lionel Richie
# Searching for ""Lady"" by Kenny Rogers...
# Done.
# Processed: "Lady" - Kenny Rogers
# Searching for ""(Just Like) Starting Over"" by John Lennon...
# Done.
# Processed: "(Just Like) Starting Over" - John Lennon
# Searching for ""Jessie's Girl"" by Rick Springfield...
# Done.
# Processed: "Jessie's Girl" - Rick Springfield
# Searching for ""Celebration"" by Kool & the Gang...
# Done.
# Processed: "Celebration" - Kool & the Gang
# Searching for ""Kiss on My List"" by Daryl Hall & John Oates...
# Done.
# Processed: "Kiss on My List" - Daryl Hall & John Oates
# Searching for ""I Love a Rainy Night"" by Eddie Rabbitt...
# Done.
# Processed: "I Love a Rainy Night" - Eddie Rabbitt
# Searching for ""9 To 5"" by Dolly Parton...
# Done.
# Processed: "9 To 5" - Dolly Parton
# Searching for ""Keep on Loving You"" by REO Speedwagon...
# Done.
# Processed: "Keep on Loving You" - REO Speedwagon
# Searching for ""Theme from The Greatest American Hero (Believe It or Not)"" by Joey Scarbury...
# Done.
# Processed: "Theme from The Greatest American Hero (Believe It or Not)" - Joey Scarbury
# Searching for ""Morning Train (Nine to Five)"" by Sheena Easton...
# Done.
# Processed: "Morning Train (Nine to Five)" - Sheena Easton
# Searching for ""Being with You"" by Smokey Robinson...
# Done.
# Processed: "Being with You" - Smokey Robinson
# Searching for ""Queen of Hearts"" by Juice Newton...
# Done.
# Processed: "Queen of Hearts" - Juice Newton
# Searching for ""Rapture"" by Blondie...
# Done.
# Processed: "Rapture" - Blondie
# Searching for ""A Woman Needs Love (Just Like You Do)"" by Raydio...
# Done.
# Processed: "A Woman Needs Love (Just Like You Do)" - Raydio
# Searching for ""The Tide Is High"" by Blondie...
# Done.
# Processed: "The Tide Is High" - Blondie
# Searching for ""Just the Two of Us"" by Grover Washington, Jr. & Bill Withers...
# Done.
# Processed: "Just the Two of Us" - Grover Washington, Jr. & Bill Withers
# Searching for ""Slow Hand"" by The Pointer Sisters...
# Done.
# Processed: "Slow Hand" - The Pointer Sisters
